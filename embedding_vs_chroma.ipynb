# %%
import os
from openai import OpenAI

API_KEY = os.environ["NVIDIA_API_KEY"]
client = OpenAI(base_url = "https://integrate.api.nvidia.com/v1",api_key=API_KEY)

# %%
EMBED_MODEL = "nvidia/nv-embedqa-e5-v5"   # or any NIM embedding model

def get_embedding(text: str):
    """Return embedding vector for a single text."""
    response = client.embeddings.create(
        model=EMBED_MODEL,
        extra_body={"input_type": "query"}, # Use "query" or "document"
        input=[text]          # input is a list
    )
    return response.data[0].embedding

# %%
import numpy as np
import chromadb
import time

def cosine_similarity(a, b):
    a, b = np.array(a), np.array(b)
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# 1. Semantic search with numpy
sentences = [
    "I love programming in Python.",
    "The Python snake is a constrictor.",
    "Machine learning is fascinating.",
    "I enjoy hiking in the mountains.",
]
query = "How do you feel about coding?"

sentence_embs = [get_embedding(s) for s in sentences]
query_emb = get_embedding(query)


sims = [cosine_similarity(query_emb, emb) for emb in sentence_embs]
top_idx = np.argmax(sims)
print(f"Query: {query}")
print(f"Top match: {sentences[top_idx]} (similarity {sims[top_idx]:.3f})")


# 2. Same with Chroma
from chromadb import Documents, EmbeddingFunction, Embeddings

class NIMEmbeddingFunction(EmbeddingFunction):
    def __call__(self, input: Documents) -> Embeddings:
        return [get_embedding(text) for text in input]

chroma_client = chromadb.Client()
collection = chroma_client.create_collection(name="test1", embedding_function=NIMEmbeddingFunction())
collection.add(documents=sentences, ids=[str(i) for i in range(len(sentences))])

results = collection.query(query_texts=[query], n_results=1)
print("Chroma top match:", results["documents"][0])
# Out:
# Query: How do you feel about coding?
# Top match: I love programming in Python. (similarity 0.704)
# /tmp/ipykernel_17441/1390200420.py:36: DeprecationWarning: The class NIMEmbeddingFunction does not implement __init__. This will be required in a future version.
#   collection = chroma_client.create_collection(name="test1", embedding_function=NIMEmbeddingFunction())
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[12], line 36
#      33         return [get_embedding(text) for text in input]
#      35 chroma_client = chromadb.Client()
# ---> 36 collection = chroma_client.create_collection(name="test1", embedding_function=NIMEmbeddingFunction())
#      37 collection.add(documents=sentences, ids=[str(i) for i in range(len(sentences))])
#      39 results = collection.query(query_texts=[query], n_results=1)
#
# File ~/.local/lib/python3.10/site-packages/chromadb/api/client.py:222, in Client.create_collection(self, name, schema, configuration, metadata, embedding_function, data_loader, get_or_create)
#     219 if embedding_function is not None and configuration_ef is None:
#     220     configuration["embedding_function"] = embedding_function
# --> 222 model = self._server.create_collection(
#     223     name=name,
#     224     schema=schema,
#     225     metadata=metadata,
#     226     tenant=self.tenant,
#     227     database=self.database,
#     228     get_or_create=get_or_create,
#     229     configuration=configuration,
#     230 )
#     231 return Collection(
#     232     client=self._server,
#     233     model=model,
#     234     embedding_function=embedding_function,
#     235     data_loader=data_loader,
#     236 )
#
# File ~/.local/lib/python3.10/site-packages/chromadb/api/rust.py:244, in RustBindingsAPI.create_collection(self, name, schema, configuration, metadata, get_or_create, tenant, database)
#     241 else:
#     242     schema_str = None
# --> 244 collection = self.bindings.create_collection(
#     245     name,
#     246     configuration_json_str,
#     247     schema_str,
#     248     metadata,
#     249     get_or_create,
#     250     tenant,
#     251     database,
#     252 )
#     253 collection_model = CollectionModel(
#     254     id=collection.id,
#     255     name=collection.name,
#    (...)
#     261     database=collection.database,
#     262 )
#     263 return collection_model
#
# InternalError: Collection [test1] already exists

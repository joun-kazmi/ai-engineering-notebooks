# %%
def fixed_chunk(text, chunk_size=500, overlap=50):
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start = end - overlap
    return chunks

# %%
# Copy and run this cell in your notebook
text = """Apple plans to release a new phone next fall. The device will feature an upgraded battery and screen.

Meanwhile, market analysts expect strong sales in Asia. Supply chains are already preparing components."""

print(text)
# Out:
# Apple plans to release a new phone next fall. The device will feature an upgraded battery and screen.
#
# Meanwhile, market analysts expect strong sales in Asia. Supply chains are already preparing components.

# %%
import re

def recursive_split(text, chunk_size=1000, chunk_overlap=200):
    # Split by paragraphs first
    paragraphs = re.split(r'\n\s*\n', text)
    chunks = []
    current_chunk = ""
    for para in paragraphs:
        if len(current_chunk) + len(para) <= chunk_size:
            current_chunk += para + "\n\n"
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            current_chunk = para + "\n\n"
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks

# %%
chunk_fixed = fixed_chunk(text, chunk_size=55, overlap=0)
chunk_recursive = recursive_split(text, chunk_size=120)
for i in chunk_fixed:
    print('chunk_fixed part ', i)
for j in chunk_recursive:
    print('chunk_recursive part ', j)
# Out:
# chunk_fixed part  Apple plans to release a new phone next fall. The devic
# chunk_fixed part  e will feature an upgraded battery and screen.
#
# Meanwhi
# chunk_fixed part  le, market analysts expect strong sales in Asia. Supply
# chunk_fixed part   chains are already preparing components.
# chunk_recursive part  Apple plans to release a new phone next fall. The device will feature an upgraded battery and screen.
# chunk_recursive part  Meanwhile, market analysts expect strong sales in Asia. Supply chains are already preparing components.
